# %%
# system
import os
import sys
import json
from pathlib import Path

import collections

# data 
import numpy as np
import polars as pl
import geopandas as gpd
import anndata as ad
import scipy as sp
# import imageio # can remove this 
import tifffile 
from skimage.filters import threshold_otsu

# plotting
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib import cm 
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from adjustText import adjust_text
from pypalettes import load_cmap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       4 sys.path.append(os.path.dirname(os.getcwd()))
#       7 # import SegQC
# ----> 8 from SegQC.plotting import stats
#      10 from pypalettes import load_cmap
#
# ModuleNotFoundError: No module named 'SegQC'

# %%
seg_qc_path = "/ceph/cephatlas/aklein/SegQC/src"
sys.path.append(seg_qc_path)

# %%
cmap_c = load_cmap("Acadia")
cmap_r = load_cmap("Alkalay1")

# %%
data = [[ 66386, 174296,  75131, 577908,  32015],
        [ 58230, 381139,  78045,  99308, 160454],
        [ 89135,  80552, 152558, 497981, 603535],
        [ 78415,  81858, 150656, 193263,  69638],
        [139361, 331509, 343164, 781380,  52269]]
columns = ('Freeze', 'Wind', 'Flood', 'Quake', 'Hail')
rows = ['%d year' % x for x in (100, 50, 20, 10, 5)]
ccolors = cmap_c.colors[:len(columns)]
rcolors = cmap_r.colors[:len(rows)]
title = "Test"

# %%
stats.plot_table(data, rows, columns, title,rcolors=rcolors, ccolors=ccolors,
                  fig_background_color="grey", fig_border="k", figsize=(6, 4))
# Out:
# (<Figure size 600x400 with 1 Axes>, <Axes: >)

# %%
import SegQC.src


SegQC.src
# Out:
# '/ceph/cephatlas/aklein/SegQC/src/SegQC'

# %%
sys.path.append(os.path.dirname(os.path.abspath(__file__)))
# Out:
# ['/gale/netapp/home2/aklein/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python312.zip',
#  '/gale/netapp/home2/aklein/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12',
#  '/gale/netapp/home2/aklein/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/lib-dynload',
#  '',
#  '/ceph/cephatlas/.venv/lib/python3.12/site-packages']

# %%
filepath_dir = "/ceph/cephatlas/merscope_data/processed/202503281042_BICAN4x1A9-E-01_VMSC31910/out/region_UCI-5224-A9-E1"
transcripts_path = f"{filepath_dir}/detected_transcripts.parquet"
image_path = f"{filepath_dir}/images"
segmentation_mask = f"{filepath_dir}/cell_boundaries.parquet"
